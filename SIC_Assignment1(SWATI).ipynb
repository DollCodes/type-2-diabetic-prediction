# %%
import pandas as pd
import numpy as np 
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
# %matplotlib inline 
import seaborn as sns

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\gillh'

# %%
df=pd.read_csv("C:\\Users\\gillh\\Downloads\\diabetes.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
df.shape
# Out:
# (768, 9)

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
def boxplot(cols):
    sns.boxplot(y=df[cols])
    plt.show()
    
for i in list(df.columns):
    boxplot(i)

# %%
sns.boxplot(y="Pregnancies", data=df)
# Out:
# <Axes: ylabel='Pregnancies'>

# %%
sns.boxplot(y="Glucose", data=df)
# Out:
# <Axes: ylabel='Glucose'>

# %%
sns.boxplot(y="BloodPressure", data=df)
# Out:
# <Axes: ylabel='BloodPressure'>

# %%
sns.boxplot(y="SkinThickness", data=df)
# Out:
# <Axes: ylabel='SkinThickness'>

# %%
sns.boxplot(y="Insulin", data=df)
# Out:
# <Axes: ylabel='Insulin'>

# %%
sns.boxplot(y="BMI", data=df)
# Out:
# <Axes: ylabel='BMI'>

# %%
sns.boxplot(y="DiabetesPedigreeFunction", data=df)
# Out:
# <Axes: ylabel='DiabetesPedigreeFunction'>

# %%
sns.boxplot(y="Age", data=df)
# Out:
# <Axes: ylabel='Age'>

# %%
sns.boxplot(y="Outcome", data=df)
# Out:
# <Axes: ylabel='Outcome'>

# %%
Q1=df.quantile(0.25)
Q3=df.quantile(0.75)
IQR=Q3-Q1
Pos_Outlier=Q3+1.5*IQR
Neg_Outlier=Q1-1.5*IQR

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df1=df[~((df<(Q1-1.5*IQR))|(df>(Q3+1.5*IQR))).any(axis=1)]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 639 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               639 non-null    int64
#  1   Glucose                   639 non-null    int64
#  2   BloodPressure             639 non-null    int64
#  3   SkinThickness             639 non-null    int64
#  4   Insulin                   639 non-null    int64
#  5   BMI                       639 non-null    float64
#  6   DiabetesPedigreeFunction  639 non-null    float64
#  7   Age                       639 non-null    int64
#  8   Outcome                   639 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 49.9 KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
Q1=df.quantile(0.25)
Q3=df.quantile(0.75)
IQR=Q3-Q1
Pos_Outlier=Q3+1.5*IQR
Neg_Outlier=Q1-1.5*IQR

# %%
print(Pos_Outlier)
# Out:
# Pregnancies                  13.500
# Glucose                     202.125
# BloodPressure               107.000
# SkinThickness                80.000
# Insulin                     318.125
# BMI                          50.550
# DiabetesPedigreeFunction      1.200
# Age                          66.500
# Outcome                       2.500
# dtype: float64

# %%
print(Neg_Outlier)
# Out:
# Pregnancies                  -6.500
# Glucose                      37.125
# BloodPressure                35.000
# SkinThickness               -48.000
# Insulin                    -190.875
# BMI                          13.350
# DiabetesPedigreeFunction     -0.330
# Age                          -1.500
# Outcome                      -1.500
# dtype: float64

# %%
df2=np.where(df<=Neg_Outlier,Neg_Outlier,np.where(df>=Pos_Outlier,Pos_Outlier,df))

# %%
df2
# Out:
# array([[  6.   , 148.   ,  72.   , ...,   0.627,  50.   ,   1.   ],
#        [  1.   ,  85.   ,  66.   , ...,   0.351,  31.   ,   0.   ],
#        [  8.   , 183.   ,  64.   , ...,   0.672,  32.   ,   1.   ],
#        ...,
#        [  5.   , 121.   ,  72.   , ...,   0.245,  30.   ,   0.   ],
#        [  1.   , 126.   ,  60.   , ...,   0.349,  47.   ,   1.   ],
#        [  1.   ,  93.   ,  70.   , ...,   0.315,  23.   ,   0.   ]])

# %%
df2.shape
# Out:
# (768, 9)

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
df2=pd.DataFrame(df2,columns=df.columns)

# %%
df2.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0          6.0    148.0           72.0           35.0      0.0  33.6
# 1          1.0     85.0           66.0           29.0      0.0  26.6
# 2          8.0    183.0           64.0            0.0      0.0  23.3
# 3          1.0     89.0           66.0           23.0     94.0  28.1
# 4          0.0    137.0           40.0           35.0    168.0  43.1
#
#    DiabetesPedigreeFunction   Age  Outcome
# 0                     0.627  50.0      1.0
# 1                     0.351  31.0      0.0
# 2                     0.672  32.0      1.0
# 3                     0.167  21.0      0.0
# 4                     1.200  33.0      1.0

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    float64
#  1   Glucose                   768 non-null    float64
#  2   BloodPressure             768 non-null    float64
#  3   SkinThickness             768 non-null    float64
#  4   Insulin                   768 non-null    float64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    float64
#  8   Outcome                   768 non-null    float64
# dtypes: float64(9)
# memory usage: 54.1 KB

# %%
df2.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.837240  121.136230      70.684896      20.511719   73.652669
# std       3.344157   31.187468      14.197239      15.844744   93.576029
# min       0.000000   37.125000      35.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      13.500000  199.000000     107.000000      80.000000  318.125000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    32.125065                  0.458914   33.199870    0.348958
# std      7.049584                  0.285596   11.628404    0.476951
# ...

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
def boxplot(cols):
    sns.boxplot(y=df2[cols])
    plt.show()
for i in list(df2.columns):
    boxplot(i)

# %%
df2.shape
# Out:
# (768, 9)

# %%
sns.pairplot(df2)

# %%
sns.displot(df2["Outcome"],kde=True)

# %%
df2.skew()
# Out:
# Pregnancies                 0.853962
# Glucose                     0.417946
# BloodPressure              -0.406036
# SkinThickness               0.026663
# Insulin                     1.173898
# BMI                         0.135809
# DiabetesPedigreeFunction    1.024428
# Age                         1.067170
# Outcome                     0.635017
# dtype: float64

# %%
df2.kurt()
# Out:
# Pregnancies                -0.070853
# Glucose                    -0.132160
# BloodPressure               0.620495
# SkinThickness              -0.981163
# Insulin                     0.407839
# BMI                         0.050053
# DiabetesPedigreeFunction    0.297447
# Age                         0.330970
# Outcome                    -1.600930
# dtype: float64

# %%
df2.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.128987       0.184307      -0.084349
# Glucose                      0.128987  1.000000       0.197865       0.059806
# BloodPressure                0.184307  0.197865       1.000000       0.152644
# SkinThickness               -0.084349  0.059806       0.152644       1.000000
# Insulin                     -0.077793  0.315856       0.050080       0.488101
# BMI                          0.024681  0.235542       0.282544       0.401494
# DiabetesPedigreeFunction    -0.017398  0.120213       0.038793       0.177920
# Age                          0.549695  0.269056       0.304208      -0.119170
# Outcome                      0.220392  0.479158       0.113301       0.073125
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.077793  0.024681                 -0.017398
# ...

# %%
df2.corr(method="spearman")
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.130724       0.185395      -0.085233
# Glucose                      0.130724  1.000000       0.235503       0.060022
# BloodPressure                0.185395  0.235503       1.000000       0.125902
# SkinThickness               -0.085233  0.060022       0.125902       1.000000
# Insulin                     -0.126111  0.212836      -0.007091       0.540815
# BMI                          0.000183  0.231149       0.292494       0.443531
# DiabetesPedigreeFunction    -0.042838  0.090872       0.030216       0.180125
# Age                          0.607189  0.285022       0.351067      -0.066857
# Outcome                      0.198689  0.475776       0.143003       0.089728
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.126111  0.000183                 -0.042838
# ...

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df2.corr(),annot=True)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df2.corr(), annot=True,cmap="coolwarm")
# Out:
# <Axes: >

# %%
df2.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
import seaborn as sns 

variables = ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
       'BMI', 'DiabetesPedigreeFunction', 'Age']

for var in variables:
    plt.figure()
    sns.regplot(x=var, y='Outcome', data=df).set(title=f'Regression plot of {var} and Outcome');

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    float64
#  1   Glucose                   768 non-null    float64
#  2   BloodPressure             768 non-null    float64
#  3   SkinThickness             768 non-null    float64
#  4   Insulin                   768 non-null    float64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    float64
#  8   Outcome                   768 non-null    float64
# dtypes: float64(9)
# memory usage: 54.1 KB

# %%
X=df2.drop(("Outcome"),axis=1)

# %%
X.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0          6.0    148.0           72.0           35.0      0.0  33.6
# 1          1.0     85.0           66.0           29.0      0.0  26.6
# 2          8.0    183.0           64.0            0.0      0.0  23.3
# 3          1.0     89.0           66.0           23.0     94.0  28.1
# 4          0.0    137.0           40.0           35.0    168.0  43.1
#
#    DiabetesPedigreeFunction   Age
# 0                     0.627  50.0
# 1                     0.351  31.0
# 2                     0.672  32.0
# 3                     0.167  21.0
# 4                     1.200  33.0

# %%
X.shape
# Out:
# (768, 8)

# %%
Y=df2["Outcome"]

# %%
Y.shape
# Out:
# (768,)

# %%
from sklearn.preprocessing import StandardScaler,MinMaxScaler,RobustScaler
scaler=StandardScaler()
X_scaled=scaler.fit_transform(X)

# %%
X_scaled
# Out:
# array([[ 0.64714967,  0.86192556,  0.09269135, ...,  0.20935933,
#          0.58892732,  1.44569096],
#        [-0.84896998, -1.15943299, -0.33020145, ..., -0.78425421,
#         -0.37810147, -0.189304  ],
#        [ 1.24559754,  1.98490253, -0.47116571, ..., -1.25267202,
#          0.74659506, -0.10325164],
#        ...,
#        [ 0.34792574, -0.00437096,  0.09269135, ..., -0.84103213,
#         -0.74949659, -0.27535637],
#        [-0.84896998,  0.15605432, -0.75309424, ..., -0.28744744,
#         -0.38510892,  1.18753386],
#        [-0.84896998, -0.90275254, -0.04827292, ..., -0.24486401,
#         -0.50423566, -0.87772293]])

# %%
X_scaled=pd.DataFrame(X_scaled,columns=X.columns)

# %%
X_scaled.head()
# Out:
#    Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0     0.647150  0.861926       0.092691       0.914986 -0.787602  0.209359
# 1    -0.848970 -1.159433      -0.330201       0.536065 -0.787602 -0.784254
# 2     1.245598  1.984903      -0.471166      -1.295388 -0.787602 -1.252672
# 3    -0.848970 -1.031093      -0.330201       0.157144  0.217583 -0.571337
# 4    -1.148194  0.508990      -2.162737       0.914986  1.008900  1.557835
#
#    DiabetesPedigreeFunction       Age
# 0                  0.588927  1.445691
# 1                 -0.378101 -0.189304
# 2                  0.746595 -0.103252
# 3                 -1.022787 -1.049828
# 4                  2.596563 -0.017199

# %%
Y
# Out:
# 0      1.0
# 1      0.0
# 2      1.0
# 3      0.0
# 4      1.0
#       ...
# 763    0.0
# 764    0.0
# 765    0.0
# 766    1.0
# 767    0.0
# Name: Outcome, Length: 768, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test,Y_train,Y_test=train_test_split(X_scaled,Y,train_size=0.80,random_state=102)

# %%
X_train.shape
# Out:
# (614, 8)

# %%
X_test.shape
# Out:
# (154, 8)

# %%
Y_train
# Out:
# 438    0.0
# 517    0.0
# 359    1.0
# 767    0.0
# 574    0.0
#       ...
# 626    0.0
# 242    1.0
# 590    1.0
# 755    1.0
# 256    0.0
# Name: Outcome, Length: 614, dtype: float64

# %%
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (614, 8)
# (154, 8)
# (614,)
# (154,)

# %%
X_train.shape
# Out:
# (614, 8)

# %%
X_test.shape
# Out:
# (154, 8)

# %%
from sklearn.linear_model import LinearRegression

# %%
lin_mod=LinearRegression()

# %%
lin_mod.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
Y_train_predict=lin_mod.predict(X_train)

# %%
Y_train_predict
# Out:
# array([-0.11898965,  0.50264949,  0.84496118,  0.08085798,  0.35217341,
#         0.34067067,  0.51982015,  1.069901  ,  0.2000538 ,  0.00976901,
#         0.21724553, -0.17424429,  0.81083813,  0.38354159,  0.23442534,
#        -0.04009738,  0.18979473,  0.60204917,  0.77381324,  0.77596177,
#         0.62108394,  0.44696281,  0.60187065,  0.93097219,  0.22334451,
#         0.7729717 ,  0.61946991,  0.7510273 ,  0.64085699,  0.277023  ,
#         0.68351   ,  0.07027774,  0.61815965,  0.81405778,  0.38677843,
#         0.36482339,  0.27481243,  0.31230531, -0.02080527,  0.16620271,
#         0.87175527,  0.71172702,  0.35889127,  0.16215466, -0.12608231,
#         0.75026985, -0.05499322,  0.83478263,  0.18531345,  0.49391149,
#        -0.03302618,  0.47067126,  0.35290825,  0.6404213 ,  0.09126607,
#         0.45901361,  0.37614534,  0.33355816,  0.66824874,  0.89595319,
#         0.17889708,  0.64451426,  0.39513512,  0.56800337,  0.18626325,
# ...

# %%
Y_train
# Out:
# 438    0.0
# 517    0.0
# 359    1.0
# 767    0.0
# 574    0.0
#       ...
# 626    0.0
# 242    1.0
# 590    1.0
# 755    1.0
# 256    0.0
# Name: Outcome, Length: 614, dtype: float64

# %%
actual_minus_predicted = sum((Y_train - Y_train_predict)**2)
actual_minus_actual_mean = sum((Y_train - Y_train.mean())**2)
r2 = 1 - actual_minus_predicted/actual_minus_actual_mean
print('R²:', r2)
# Out:
# R²: 0.3214602122811052

# %%
lin_mod.score(X_train, Y_train)
# Out:
# 0.32146021228110533

# %%
print(lin_mod.intercept_)
# Out:
# 0.35965241338973025

# %%
print(lin_mod.coef_)
# Out:
# [ 0.07026602  0.19631702 -0.04192832  0.01196025 -0.0301682   0.10165042
#   0.05508783  0.02615165]

# %%
coeff_df = pd.DataFrame(lin_mod.coef_,X_train.columns,columns=['Coefficient'])
coeff_df
# Out:
#                           Coefficient
# Pregnancies                  0.070266
# Glucose                      0.196317
# BloodPressure               -0.041928
# SkinThickness                0.011960
# Insulin                     -0.030168
# BMI                          0.101650
# DiabetesPedigreeFunction     0.055088
# Age                          0.026152

# %%
Y_predict_test=lin_mod.predict(X_test)

# %%
Y_predict_test
# Out:
# array([ 0.19527367,  0.18606728,  0.13611323,  0.4072527 ,  0.24770343,
#         0.64762859,  0.33311144,  0.11294844,  0.58047148,  0.48411662,
#         0.25048663,  0.37869741,  0.28548858,  0.88892258,  0.45584006,
#         0.1311344 , -0.10520306,  0.78142075,  0.25697814,  0.24250831,
#         0.35465528,  0.25503805,  0.79429862,  0.09921689,  0.42777685,
#         0.24041463,  0.26708983,  0.64190953,  0.3782195 ,  0.77042774,
#         0.44155567,  0.09270063,  0.25408783,  0.47497258,  0.3897083 ,
#         0.11059189,  0.34393729,  0.61989561,  0.22098349,  0.11042909,
#         0.29341462,  0.67086415,  0.19908781,  0.34275751, -0.08211719,
#         0.71817903,  0.26579283,  0.54973928,  0.64306059,  0.56576254,
#        -0.10736084,  0.03014848,  0.14685271,  0.60208592,  0.58969043,
#         0.21465327,  0.34269731,  0.42757003,  0.2986497 ,  0.3087391 ,
#        -0.02428557,  0.72096255,  0.47055201,  0.69385099,  0.83238251,
# ...

# %%
Y_test
# Out:
# 508    0.0
# 512    0.0
# 654    0.0
# 189    1.0
# 709    1.0
#       ...
# 264    1.0
# 318    0.0
# 34     0.0
# 385    0.0
# 20     0.0
# Name: Outcome, Length: 154, dtype: float64

# %%
lin_mod.score(X_test, Y_test)
# Out:
# 0.2842152519363593

# %%
final=pd.DataFrame()

# %%
final["Y_test"]=Y_test

# %%
final["Y_predicted"]=Y_predict_test

# %%
final.head(10)
# Out:
#      Y_test  Y_predicted
# 508     0.0     0.195274
# 512     0.0     0.186067
# 654     0.0     0.136113
# 189     1.0     0.407253
# 709     1.0     0.247703
# 746     1.0     0.647629
# 289     0.0     0.333111
# 527     0.0     0.112948
# 548     0.0     0.580471
# 46      0.0     0.484117

# %%
test_score=lin_mod.score(X_test,Y_test)
print("test score",test_score)
# Out:
# test score 0.2842152519363593

# %%
train_score=lin_mod.score(X_train,Y_train)
print("train score",train_score)
# Out:
# train score 0.32146021228110533

# %%
import pandas as pd
details={
    'Pregnancies':[0,3,56,6,],
    'Glucose':[113,243,34,232],
    'BloodPressure':[45,35,26,78],
    'SkinThickness':[45,25,16,5,],
    'Insulin':[242,434,456,523],
    'BMI':[23.4,54.3,56.3,64.3],
    'DiabetesPedigreeFunction':[0.342,0.432,0.453,0.423],
    'Age':[23,45,25,76],
}
df_new = pd.DataFrame(details)
df_new
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            0      113             45             45      242  23.4
# 1            3      243             35             25      434  54.3
# 2           56       34             26             16      456  56.3
# 3            6      232             78              5      523  64.3
#
#    DiabetesPedigreeFunction  Age
# 0                     0.342   23
# 1                     0.432   45
# 2                     0.453   25
# 3                     0.423   76

# %%
df_predict_new=lin_mod.predict(df_new)

# %%
df1=df_new.copy()

# %%
df1["Outcome_predicted"]=df_predict_new

# %%
df1.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            0      113             45             45      242  23.4
# 1            3      243             35             25      434  54.3
# 2           56       34             26             16      456  56.3
# 3            6      232             78              5      523  64.3
#
#    DiabetesPedigreeFunction  Age  Outcome_predicted
# 0                     0.342   23          16.893155
# 1                     0.432   45          40.734242
# 2                     0.453   25           2.715521
# 3                     0.423   76          35.885169

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(Y_test,Y_predict_test)
from sklearn.metrics import mean_squared_error
mean_squared_error(Y_test,Y_predict_test)
# Out:
# 0.1499417536001082

# %%
from sklearn.metrics import median_absolute_error
median_absolute_error(Y_test,Y_predict_test)
# Out:
# 0.2905969383798394

# %%
from sklearn import metrics
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
LR_mse=np.sqrt(mean_squared_error(Y_test,Y_predict_test))
print("mean square error LR : ",LR_mse )
# Out:
# mean square error LR :  0.38722313154059923

# %%
rmse = np.sqrt(LR_mse)

# %%
print("Mean absolute error LR : ", mean_absolute_error(Y_test,Y_predict_test))
# Out:
# Mean absolute error LR :  0.3292293599025557

# %%
print("R2 score or accuracy LR : ", r2_score(Y_test,Y_predict_test))
# Out:
# R2 score or accuracy LR :  0.2842152519363593

# %%
from sklearn.metrics import max_error as ME
from sklearn.metrics import mean_squared_error as MSE
from sklearn.metrics import median_absolute_error as MAE
from sklearn.metrics import r2_score

# %%
original_data = Y_test
predicted_data = Y_predict_test
E2=MSE(original_data,predicted_data)
print("MEAN SQUARE ERROR IS : "  ,E2 )
E3=np.sqrt(mean_squared_error(original_data,predicted_data))
print("ROOT MEAN SQUARE ERROR IS : "  ,E3 )
E4=MAE(original_data,predicted_data)
print("MEAN ABSOLUTE ERROR IS : "  ,E4 )
E5=r2_score(original_data,predicted_data)
print("R2 Score VALUE Accuracy IS : ",E5 )
# Out:
# MEAN SQUARE ERROR IS :  0.1499417536001082
# ROOT MEAN SQUARE ERROR IS :  0.38722313154059923
# MEAN ABSOLUTE ERROR IS :  0.2905969383798394
# R2 Score VALUE Accuracy IS :  0.2842152519363593

# %%
sns.distplot((Y_test-Y_predict_test),bins=50)
# Out:
# <Axes: xlabel='Outcome', ylabel='Density'>

# %%
delta=Y_test-Y_predict_test
sns.set_style("whitegrid")
sns.kdeplot(np.array(delta),bw=0.5)
# Out:
# <Axes: ylabel='Density'>

# %%
sns.distplot((Y_predict_test),bins=50)
# Out:
# <Axes: ylabel='Density'>

# %%
from sklearn.model_selection import cross_val_score

# %%
results_10=cross_val_score(lin_mod, X_scaled, Y, cv=10, scoring="r2")

# %%
results_10
# Out:
# array([ 0.18466446,  0.32971389,  0.28772897,  0.24150823,  0.29227822,
#         0.342659  , -0.00890982,  0.47728164,  0.26777913,  0.32374992])

# %%
print(cross_val_score(lin_mod, X_scaled, Y, cv=10, scoring="r2").mean())
# Out:
# 0.27384536533030235

# %%
sns.regplot( x=Y_test, y=Y_predict_test)
plt.xlabel("True Value Y test")
plt.ylabel("Predicted Value Y Predicted")
# Out:
# Text(0, 0.5, 'Predicted Value Y Predicted')

# %%
import matplotlib.cm as cm
plt.scatter(Y_test,Y_predict_test)
plt.xlabel("True Value Y test")
plt.ylabel("Predicted Value Y Predicted")
# Out:
# Text(0, 0.5, 'Predicted Value Y Predicted')

# %%
print(lin_mod.intercept_)
# Out:
# 0.35965241338973025

# %%
print(lin_mod.coef_)
# Out:
# [ 0.07026602  0.19631702 -0.04192832  0.01196025 -0.0301682   0.10165042
#   0.05508783  0.02615165]

# %%
coeff_df = pd.DataFrame(lin_mod.coef_,X_train.columns,columns=['Coefficient'])
coeff_df
# Out:
#                           Coefficient
# Pregnancies                  0.070266
# Glucose                      0.196317
# BloodPressure               -0.041928
# SkinThickness                0.011960
# Insulin                     -0.030168
# BMI                          0.101650
# DiabetesPedigreeFunction     0.055088
# Age                          0.026152

# %%
from sklearn.linear_model import LinearRegression,Ridge,RidgeCV,LassoCV,ElasticNet,ElasticNetCV

# %%
from sklearn.model_selection import train_test_split

# %%
import statsmodels.api as sma

# %%
lasso_model=LassoCV(cv=10,max_iter=1000)

# %%
lasso_model.fit(X_train, Y_train)
# Out:
# LassoCV(cv=10)

# %%
lasso_model.score(X_test, Y_test)
# Out:
# 0.286307819887763

# %%
ridgecv=RidgeCV(cv=10)
ridgecv.fit(X_train,Y_train)
ridgecv.score(X_test,Y_test)
# Out:
# 0.2843447989032396

# %%
from sklearn.metrics import r2_score

# %%
r2_score(Y_test,Y_predict_test)
# Out:
# 0.2842152519363593

# %%
r2_score(Y_predict_test,Y_test)
# Out:
# -1.596246944289509

# %%
from sklearn.model_selection import cross_val_score
print(cross_val_score(lin_mod, X, Y, cv=10, scoring="r2").mean())
# Out:
# 0.27384536533030235

# %%
X_train.head()
# Out:
#      Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 438    -0.848970 -0.774412      -0.048273      -0.348085 -0.787602 -1.976590
# 517     0.946374  0.123969       1.079441      -1.295388 -0.787602  0.777138
# 359    -0.848970  2.402008       0.374620       0.978140  1.875070  0.620999
# 767    -0.848970 -0.902753      -0.048273       0.662372 -0.787602 -0.244864
# 574    -0.848970  0.701500       1.079441       0.599219  2.614256 -0.287447
#
#      DiabetesPedigreeFunction       Age
# 438                 -1.092862 -1.049828
# 517                 -0.542777  1.531743
# 359                  1.457852 -0.361409
# 767                 -0.504236 -0.877723
# 574                  1.517415 -0.877723

# %%
Y_train.head()
# Out:
# 438    0.0
# 517    0.0
# 359    1.0
# 767    0.0
# 574    0.0
# Name: Outcome, dtype: float64

# %%
from sklearn.linear_model import Lasso
from sklearn.model_selection import GridSearchCV

# %%
LassoReg = Lasso()
parameters = {'alpha':[0,0.1,0.5,1,5,10],'fit_intercept': [True,False]}

Lasso_reg= GridSearchCV(LassoReg, parameters, scoring='neg_mean_squared_error',cv=20)

# %%
# %%time
Lasso_reg.fit(X_train,Y_train)
# Out:
# CPU times: total: 547 ms
# Wall time: 1.35 s
# GridSearchCV(cv=20, estimator=Lasso(),
#              param_grid={'alpha': [0, 0.1, 0.5, 1, 5, 10],
#                          'fit_intercept': [True, False]},
#              scoring='neg_mean_squared_error')

# %%
print(Lasso_reg.best_estimator_)
best_model = Lasso_reg.best_estimator_
best_model.fit(X_train,Y_train)
y_predicted = best_model.predict(X_test)
print(best_model.score(X_train,Y_train)*100)
# Out:
# Lasso(alpha=0)
# 32.146021228110534

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV
parameters = {'alpha':[0.001,0.01,0.1,0.2,0.4, 0.5,0.7,0.9,1,5,10]}
             
RidgeReg = Ridge()
Ridge_reg= GridSearchCV(RidgeReg, parameters, scoring='neg_mean_squared_error',cv=20)

# %%
# %%time
Ridge_reg.fit(X_train,Y_train)
# Out:
# CPU times: total: 859 ms
# Wall time: 1.32 s
# GridSearchCV(cv=20, estimator=Ridge(),
#              param_grid={'alpha': [0.001, 0.01, 0.1, 0.2, 0.4, 0.5, 0.7, 0.9, 1,
#                                    5, 10]},
#              scoring='neg_mean_squared_error')

# %%
print(Ridge_reg.best_estimator_)
best_model = Ridge_reg.best_estimator_
best_model.fit(X_train,Y_train)
y_predicted = best_model.predict(X_test)
print(best_model.score(X_train,Y_train)*100)
# Out:
# Ridge(alpha=10)
# 32.13841169328453

# %%
data=pd.read_csv("C:\\users\\gillh\\Downloads\\diabetes.csv")

# %%
df=data.copy()

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df["Outcome"].value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
df["Outcome"].value_counts(normalize=True)
# Out:
# Outcome
# 0    0.651042
# 1    0.348958
# Name: proportion, dtype: float64

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
from sklearn.svm import SVC,SVR

# %%
svr_model=SVR(kernel="poly",degree=8,C=0.1,gamma=0.01,verbose=True)

# %%
svr_model.fit(X_train,Y_train)
# Out:
# [LibSVM]
# SVR(C=0.1, degree=8, gamma=0.01, kernel='poly', verbose=True)
